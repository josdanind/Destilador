# %% [markdown]
# # Destilador De Alcohol
#
# ## 1. Iniciar Programa

# %%
# !python3 index.py -t 30
# Out:
# ------------------------------------------------------------
# | setPoint_(°C) | Temperatura_(°C) | Output | Tiempo_(min) |
# ------------------------------------------------------------
# |     30.00     |      27.25       |  0.00  |     0.00     |
# ------------------------------------------------------------
# ------------------------------------------------------------
# | setPoint_(°C) | Temperatura_(°C) | Output | Tiempo_(min) |
# ------------------------------------------------------------
# |     30.00     |      27.25       |  3.30  |     0.02     |
# ------------------------------------------------------------
# ------------------------------------------------------------
# | setPoint_(°C) | Temperatura_(°C) | Output | Tiempo_(min) |
# ------------------------------------------------------------
# |     30.00     |      27.31       |  3.78  |     0.03     |
# ------------------------------------------------------------
# ...

# %%
import time

fecha = time.strftime("%d%m%y") + ".dat"
print(fecha)
# Out:
# 030520.dat
